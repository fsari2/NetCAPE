# %% [markdown]
# ### Calculation NetCAPE with Water Loading Consideration
#
# This script uses the Fortran routines in CAPET to calculate CAPE for different temperature levels and spatially averaged across the domain (excluding convection [defined as dBZ>0])
# Fortran routines were provided by Lasher-Trapp, Sonia (SLT).
#
# Subroutine is called "getcape" and is in the capeT.f90 routine.
# SLT tested using Testcape.F
# Driver routine can be used to do the calculations on all model grid columns
#
# Required:
# - Number of levels in the sounding (nk)
# - Pressure of each sounding level in mb (hPa)
# - Temperature of each sounding level in ºC
# - Water vapor mixing ratio in kg/kg
# - *If sounding only has dewpoint temperature, see code in Testcape.f for converting to qv
#
# Must pass the variable 'source' as an integer:
# - Surface (1)
# - Most unstable, i.e. max theta-e (2)
# - Mixed layer, where you must specify the ml_depth, defaults to 500 m (3)
# - *Most unstable (option 2) is what WRF-Python CAPE 2D function uses and is what was used for the environmental CAPE data in paper 1
#
#
# Outputs (all in J/kg):
# - CAPE from LFC to 0ºC isotherm (cape_0c)
# - CAPE from LFC to -10ºC isotherm (cape_10c)
# - CAPE from LFC to -20ºC isotherm (cape_20c)
# - Difference in CAPE & CIN for LFC to 0ºC (cape0c_cin)
# - Difference in CAPE & CIN for LFC to -10ºC (cape10c_cin)
# - Difference in CAPE & CIN for LFC to -20ºC (cape20c_cin)

# %% [markdown]
# # Compiling CAPET.f90 (single grid column)

# %% [markdown]
# ## Running f2py
# See: https://numpy.org/doc/stable/f2py/f2py.getting-started.html  - (The smart way [fib2])
#
# and especially:
# https://gist.github.com/shane5ul/79340646ba0a4487c9da50b805215369
#
# ### Summary of steps:
#
#     -Creating the signature file that contains descriptions of wrappers to Fortran
#
#     -F2PY reads a signature file and writes a Python C/API module containing Fortran/C/Python bindings
#
#     -F2PY compiles all sources and builds an extension module containing the wrappers

# %%
# Wrap the Fortran subroutine by creating a signature file 
# NOTE: if running in Jupyter, must include "!" at beginning since not on Command line

# !rm capeT.pyf
    # Remove any existing version of .pyf file that might mess things up 
    
# !f2py -m getcapeT -h capeT.pyf capeT.f90
#f2py -m module_name -h sig_file.pyf list_of_fortran_files

print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
# !cat capeT.pyf
    #The .pyf file provides an interface so that the python program and Fortran subroutine can talk to each other
# Out:
# Reading fortran codes...
# 	Reading file 'capeT.f90' (format:fix)
# Post-processing...
# 	Block: getcapeT
# 			Block: getcape
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# 			Block: getqvl
# In: :getcapeT:capeT.f90:getqvl
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# 			Block: getqvi
# In: :getcapeT:capeT.f90:getqvi
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# 			Block: getthx
# 			Block: gettd
# In: :getcapeT:capeT.f90:gettd
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# Applying post-processing hooks...
#   character_backward_compatibility_hook
# Post-processing (stage 2)...
# Saving signatures to file "./capeT.pyf"
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# !    -*- f90 -*-
# ! Note: the context of this file is case sensitive.
#
# python module getcapeT ! in
#     interface  ! in :getcapeT
#         subroutine getcape(source,nk,p_in,t_in,q_in,cape,cin,cape_0c,cape_10c,cape_20c,cape0c_cin,cape10c_cin,cape20c_cin,zlcl,zlfc,zel,psource,tsource,qvsource) ! in :getcapeT:capeT.f90
#             integer intent(in) :: source
#             integer, optional,intent(in),check(shape(p_in, 0) == nk),depend(p_in) :: nk=shape(p_in, 0)
#             real dimension(nk),intent(in) :: p_in
#             real dimension(nk),intent(in),depend(nk) :: t_in
#             real dimension(nk),intent(in),depend(nk) :: q_in
#             real intent(out) :: cape
#             real intent(out) :: cin
#             real intent(out) :: cape_0c
#             real intent(out) :: cape_10c
#             real intent(out) :: cape_20c
#             real intent(out) :: cape0c_cin
#             real intent(out) :: cape10c_cin
#             real intent(out) :: cape20c_cin
#             real :: zlcl
#             real :: zlfc
#             real :: zel
#             real intent(out) :: psource
#             real intent(out) :: tsource
#             real intent(out) :: qvsource
#         end subroutine getcape
#         function getqvl(p,t) ! in :getcapeT:capeT.f90
#             real :: p
#             real :: t
#             real :: getqvl
#         end function getqvl
#         function getqvi(p,t) ! in :getcapeT:capeT.f90
#             real :: p
#             real :: t
#             real :: getqvi
#         end function getqvi
#         function getthx(p,t,td,q) ! in :getcapeT:capeT.f90
#             real :: p
#             real :: t
#             real :: td
#             real :: q
#             real :: getthx
#         end function getthx
#         function gettd(p,t,q) ! in :getcapeT:capeT.f90
#             real :: p
#             real :: t
#             real :: q
#             real :: gettd
#         end function gettd
#     end interface
# end python module getcapeT
#
# ! This file was auto-generated with f2py (version:1.24.4).
# ! See:
# ! https://web.archive.org/web/20140822061353/http://cens.ioc.ee/projects/f2py2e

# %%
# Compile the file 
# Use the -c flag; there may be a bunch of warnings thrown up

# !f2py -c -m getcapeT capeT.f90
    #!f2py -c sig_file.pyf list_of_fortran_files
# Out:
# running build
# running config_cc
# INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# INFO: build_src
# INFO: building extension "getcapeT" sources
# INFO: f2py options: []
# INFO: f2py:> /glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8/getcapeTmodule.c
# creating /glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8
# Reading fortran codes...
# 	Reading file 'capeT.f90' (format:fix)
# Post-processing...
# 	Block: getcapeT
# 			Block: getcape
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# In: :getcapeT:capeT.f90:getcape
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# 			Block: getqvl
# In: :getcapeT:capeT.f90:getqvl
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# 			Block: getqvi
# In: :getcapeT:capeT.f90:getqvi
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# 			Block: getthx
# 			Block: gettd
# In: :getcapeT:capeT.f90:gettd
# get_parameters: got "eval() arg 1 must be a string, bytes or code object" on 4
# Applying post-processing hooks...
#   character_backward_compatibility_hook
# Post-processing (stage 2)...
# Building modules...
#     Building module "getcapeT"...
#     Generating possibly empty wrappers"
#     Maybe empty "getcapeT-f2pywrappers.f"
#         Constructing wrapper function "getcape"...
#           cape,cin,cape_0c,cape_10c,cape_20c,cape0c_cin,cape10c_cin,cape20c_cin,psource,tsource,qvsource = getcape(source,p_in,t_in,q_in,zlcl,zlfc,zel,[nk])
#     Generating possibly empty wrappers"
#     Maybe empty "getcapeT-f2pywrappers.f"
# 		Creating wrapper for Fortran function "getqvl"("getqvl")...
#         Constructing wrapper function "getqvl"...
#           getqvl = getqvl(p,t)
#     Generating possibly empty wrappers"
#     Maybe empty "getcapeT-f2pywrappers.f"
# 		Creating wrapper for Fortran function "getqvi"("getqvi")...
#         Constructing wrapper function "getqvi"...
#           getqvi = getqvi(p,t)
#     Generating possibly empty wrappers"
#     Maybe empty "getcapeT-f2pywrappers.f"
# 		Creating wrapper for Fortran function "getthx"("getthx")...
#         Constructing wrapper function "getthx"...
#           getthx = getthx(p,t,td,q)
#     Generating possibly empty wrappers"
#     Maybe empty "getcapeT-f2pywrappers.f"
# 		Creating wrapper for Fortran function "gettd"("gettd")...
#         Constructing wrapper function "gettd"...
#           gettd = gettd(p,t,q)
#     Wrote C/API module "getcapeT" to file "/glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8/getcapeTmodule.c"
#     Fortran 77 wrappers are saved to "/glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8/getcapeT-f2pywrappers.f"
# INFO:   adding '/glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8/fortranobject.c' to sources.
# INFO:   adding '/glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8' to include_dirs.
# copying /glade/u/home/fsari/.local/lib/python3.8/site-packages/numpy/f2py/src/fortranobject.c -> /glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8
# copying /glade/u/home/fsari/.local/lib/python3.8/site-packages/numpy/f2py/src/fortranobject.h -> /glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8
# INFO:   adding '/glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8/getcapeT-f2pywrappers.f' to sources.
# INFO: build_src: building npy-pkg config files
# /glade/u/apps/opt/conda/envs/npl-2022b/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running build_ext
# INFO: customize UnixCCompiler
# INFO: customize UnixCCompiler using build_ext
# INFO: get_default_fcompiler: matching types: '['arm', 'gnu95', 'intel', 'lahey', 'pg', 'nv', 'absoft', 'nag', 'vast', 'compaq', 'intele', 'intelem', 'gnu', 'g95', 'pathf95', 'nagfor', 'fujitsu']'
# INFO: customize ArmFlangCompiler
# WARN: Could not locate executable armflang
# INFO: customize Gnu95FCompiler
# INFO: Found executable /glade/u/apps/casper/24.12/spack/opt/spack/gcc/12.4.0/5b5c/bin/gfortran
# INFO: customize Gnu95FCompiler
# INFO: customize Gnu95FCompiler using build_ext
# INFO: building 'getcapeT' extension
# INFO: compiling C sources
# INFO: C compiler: gcc -pthread -B /glade/u/apps/opt/conda/envs/npl-2022b/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /glade/u/apps/opt/conda/envs/npl-2022b/include -fPIC -O2 -isystem /glade/u/apps/opt/conda/envs/npl-2022b/include -fPIC
#
# creating /glade/derecho/scratch/fsari/tmp/tmp82of97b5/glade
# creating /glade/derecho/scratch/fsari/tmp/tmp82of97b5/glade/derecho
# creating /glade/derecho/scratch/fsari/tmp/tmp82of97b5/glade/derecho/scratch
# creating /glade/derecho/scratch/fsari/tmp/tmp82of97b5/glade/derecho/scratch/fsari
# creating /glade/derecho/scratch/fsari/tmp/tmp82of97b5/glade/derecho/scratch/fsari/tmp
# creating /glade/derecho/scratch/fsari/tmp/tmp82of97b5/glade/derecho/scratch/fsari/tmp/tmp82of97b5
# creating /glade/derecho/scratch/fsari/tmp/tmp82of97b5/glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8
# INFO: compile options: '-DNPY_DISABLE_OPTIMIZATION=1 -I/glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8 -I/glade/u/home/fsari/.local/lib/python3.8/site-packages/numpy/core/include -I/glade/u/apps/opt/conda/envs/npl-2022b/include/python3.8 -c'
# INFO: gcc: /glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8/getcapeTmodule.c
# INFO: gcc: /glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8/fortranobject.c
# INFO: compiling Fortran sources
# INFO: Fortran f77 compiler: /glade/u/apps/casper/24.12/spack/opt/spack/gcc/12.4.0/5b5c/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran f90 compiler: /glade/u/apps/casper/24.12/spack/opt/spack/gcc/12.4.0/5b5c/bin/gfortran -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran fix compiler: /glade/u/apps/casper/24.12/spack/opt/spack/gcc/12.4.0/5b5c/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# INFO: compile options: '-I/glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8 -I/glade/u/home/fsari/.local/lib/python3.8/site-packages/numpy/core/include -I/glade/u/apps/opt/conda/envs/npl-2022b/include/python3.8 -c'
# INFO: gfortran:fix: capeT.f90
# capeT.f90:459:23:
#
#   459 |       pql(k) = qcldbase -qv2
#       |                       1
# Error: Symbol 'qcldbase' at (1) has no IMPLICIT type; did you mean 'qlbar'?
# capeT.f90:274:13:
#
#   274 |       th2  = avgth
#       |             1
# Warning: Possible change of value in conversion from REAL(8) to REAL(4) at (1) [-Wconversion]
# capeT.f90:275:13:
#
#   275 |       qv2  = avgqv
#       |             1
# Warning: Possible change of value in conversion from REAL(8) to REAL(4) at (1) [-Wconversion]
# error: Command "/glade/u/apps/casper/24.12/spack/opt/spack/gcc/12.4.0/5b5c/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops -I/glade/derecho/scratch/fsari/tmp/tmp82of97b5/src.linux-x86_64-3.8 -I/glade/u/home/fsari/.local/lib/python3.8/site-packages/numpy/core/include -I/glade/u/apps/opt/conda/envs/npl-2022b/include/python3.8 -c -c capeT.f90 -o /glade/derecho/scratch/fsari/tmp/tmp82of97b5/capeT.o" failed with exit status 1

# %%
# If the above step worked, it should compile a Python module (capeT)

import getcapeT
help(getcapeT)
    #Make sure understand the Python module 
    
# NOTE: that the order in which variables (input or output) are expected may differ from the Fortran subroutine
# Out:
# Help on module getcapeT:
#
# NAME
#     getcapeT
#
# DESCRIPTION
#     This module 'getcapeT' is auto-generated with f2py (version:1.24.4).
#     Functions:
#         cape,cin,cape_0c,cape_10c,cape_20c,cape0c_cin,cape10c_cin,cape20c_cin,psource,tsource,qvsource = getcape(source,p_in,t_in,q_in,zlcl,zlfc,zel,nk=shape(p_in, 0))
#         getqvl = getqvl(p,t)
#         getqvi = getqvi(p,t)
#         getthx = getthx(p,t,td,q)
#         gettd = gettd(p,t,q)
#     .
#
# DATA
#     __f2py_numpy_version__ = '1.24.4'
#     getcape = <fortran function getcape>
#     getqvi = <fortran getqvi>
#     getqvl = <fortran getqvl>
#     gettd = <fortran gettd>
#     getthx = <fortran getthx>
#
# VERSION
#     1.24.4
#
# FILE
#     /glade/u/home/fsari/script-plot/CAPET/getcapeT.cpython-38-x86_64-linux-gnu.so

# %%
# Import needed packages 
import numpy as np
from numpy import f2py
import netCDF4
from netCDF4 import Dataset
import xarray as xr
import pandas as pd

from wrf import get_basemap, getvar, latlon_coords, smooth2d, to_np, vinterp

import os,glob
from datetime import datetime, timedelta

from matplotlib.cm import get_cmap
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import matplotlib.patches as mpatches


#Comment out if using as a .py and plotting 
# %matplotlib inline

# %%
### Open Dataset (Just For Example)

a1 = xr.open_dataset("/glade/work/fsari/doc_proj/WRF/DATA/03202023/wrfout_d03_2023-03-20_03:00:00")

# %% [markdown]
# ## 30 Minutes-Averaged of 30 Mins Before Cloud Initiation

# %%
### Define function to grab all the needed variables

def grab_variables (df, t1, t2, x1, x2, y1, y2):
    # Calculate true gridbox pressure & temperature (WRF uses theta) 
    t_tes = df['T'][t1:t2, :, x1:x2, y1:y2].values
    p_tes = df['P'][t1:t2, :, x1:x2, y1:y2].values
    pb_tes = df['PB'][t1:t2, :, x1:x2, y1:y2].values
    temptheta  = t_tes.mean(axis=0)   # Units: K -- note this is a potential temperature-- conversion done in time loop 
    pertpres   = p_tes.mean(axis=0)      # Units: Pa
    basepres   = pb_tes.mean(axis=0)     # Units: Pa
    theta = temptheta + 300.
    presPa = pertpres + basepres
    pres = presPa/100.
    temp = theta*(presPa/100000.)**(2./7.) - 273.15
    
    # Water vapor mixing ratio (kg/kg)
    qv_tes = df['QVAPOR'][t1:t2, :, x1:x2, y1:y2].values
    qv = qv_tes.mean(axis=0)
    
    # Lat/lon will be same for all simulations of the same date so just need to read in from one file
    lat_tes = df['XLAT'][t1:t2, x1:x2, y1:y2].values
    lat = lat_tes.mean(axis=0)
    lon_tes = df['XLONG'][t1:t2, x1:x2, y1:y2].values
    lon = lon_tes.mean(axis=0)
    
    # Set domain bounds 
    lat_s = np.min(lat)
    lat_n = np.max(lat)
    lon_w = np.min(lon)
    lon_e = np.max(lon)
    
    return(pres, temp, qv, lat, lon, lat_s, lat_n, lon_w, lon_e)

# %%
### grab all data for whole cases

dfa_sel  = grab_variables(a1, 42, 49, 129, 163, 102, 174) #different size blue area

print(dfa_sel[0].shape)
# Out:
# (44, 34, 72)
# (44, 51, 39)

# %%
### Define function to grab all the needed variables (skipping every 10th grid point)
def grab_variables(df, t1, t2, x1, x2, y1, y2):
    # Calculate true gridbox pressure & temperature (WRF uses theta) 
    t_tes = df['T'][t1:t2, :, x1:x2:10, y1:y2:10].values  # Skip every 10th gridpoint
    p_tes = df['P'][t1:t2, :, x1:x2:10, y1:y2:10].values
    pb_tes = df['PB'][t1:t2, :, x1:x2:10, y1:y2:10].values
    temptheta = t_tes.mean(axis=0)   # Units: K -- note this is a potential temperature-- conversion done in time loop 
    pertpres = p_tes.mean(axis=0)     # Units: Pa
    basepres = pb_tes.mean(axis=0)    # Units: Pa
    theta = temptheta + 300.
    presPa = pertpres + basepres
    pres = presPa / 100.
    temp = theta * (presPa / 100000.) ** (2./7.) - 273.15
    
    # Water vapor mixing ratio (kg/kg)
    qv_tes = df['QVAPOR'][t1:t2, :, x1:x2:10, y1:y2:10].values
    qv = qv_tes.mean(axis=0)
    
    # Lat/lon will be same for all simulations of the same date so just need to read in from one file
    lat_tes = df['XLAT'][t1:t2, x1:x2:10, y1:y2:10].values
    lat = lat_tes.mean(axis=0)
    lon_tes = df['XLONG'][t1:t2, x1:x2:10, y1:y2:10].values
    lon = lon_tes.mean(axis=0)
    
    # Set domain bounds 
    lat_s = np.min(lat)
    lat_n = np.max(lat)
    lon_w = np.min(lon)
    lon_e = np.max(lon)
    
    return pres, temp, qv, lat, lon, lat_s, lat_n, lon_w, lon_e

# %%
# See the results 

print('Total CAPE:', np.round(tes[0], 1))
print('Total CIN:', np.round(tes[1], 1))
print('--------')
print('CAPE from LFC to 0ºC:', np.round(tes[2], 1))
print('CAPE from LFC to -10ºC:', np.round(tes[3], 1))
print('CAPE from LFC to -20ºC:', np.round(tes[4], 1))
print('--------')
print('NetCAPE for LFC to 0ºC layer:', np.round(tes[5], 1))
print('NetCAPE for LFC to -10ºC layer:', np.round(tes[6], 1))
print('NetCAPE for LFC to -20ºC layer:', np.round(tes[7], 1))
print('--------')
print('CAPE from -10ºC layer and above :', np.round(tes[0], 1) - np.round(tes[3], 1))
# Out:
# Total CAPE: 2559.0
# Total CIN: 0.0
# --------
# CAPE from LFC to 0ºC: 595.8
# CAPE from LFC to -10ºC: 778.6
# CAPE from LFC to -20ºC: 1017.6
# --------
# Net CAPE for LFC to 0ºC layer: 595.8
# Net CAPE for LFC to -10ºC layer: 778.6
# Net CAPE for LFC to -20ºC layer: 1017.6
# --------
# CAPE from -10ºC layer and above : 1780.4
